# %%
import requests
import json
import urllib
import  urllib.parse
import pandas as pd
import getpass
from requests.auth import HTTPBasicAuth
token = ''

# %%
from ikewaipy.ikewai import Ikewai

# %%
#Setup a client object for connecting to Ike Wai so we can get auth token
ike = Ikewai(username='ckkondo')

# %%
#login with your UH credentials
ike.login()
# Out:
#  ············
# Login  Successful - token has been set and will be valid for 240 minutes. You can now access Ike Wai data.

# %%
#this is how we access our Auth Token
ike.token
# Out:
# '1be4ae684bd69ecab3916c7c5eb72f22'

# %%
#This is how we use the ikewaipy search for JSON metadata objects - similiar to listMetadata

#ike.searchMetadata("{'name':'Variable','value.variable_name':'Temperature'}", 1)

ike.searchMetadata("{'name':'Micro_GPS_TEST'}", 1)
# Out:
# [{'uuid': '8382521003415179756-242ac1110-0001-012',
#   'owner': 'ckkondo',
#   'schemaId': None,
#   'internalUsername': None,
#   'associationIds': [],
#   'lastUpdated': '2022-03-23T12:41:22.327-05:00',
#   'name': 'Micro_GPS_TEST',
#   'value': {'x': 35,
#    'location': 'Bog.1900m',
#    'watershed': 'HONOKOHAU',
#    'site_enviro': 'NativeForest',
#    'site_type': 'Bog',
#    'site_salinity': 'Freshwater',
#    'lattitude': 20.9058874,
#    'longitude': -156.5925963,
#    'elevation': 1501.5,
#    'max_elevation_watershed-m': 1761.0,
#    'wsp': 0.852640545,
#    'group_by_water_shed_percent': 'MAUKA.1',
#    'group_by_elevation': 'MAUKA.1',
#    'distribution': 6,
#    'watershed_order': 'HONOKOHAU_6',
#    'mauka': 'MAUKA',
#    'norm_order': 2,
#    'norm_watershed_order': 'HONOKOHAU_2',
#    'watershed_mauka': 'HONOKOHAU_MAUKA',
#    'type_norm_order': '1.Pristine_HONOKOHAU_2',
#    'loc': {'type': 'Point', 'coordinates': [-156.5925963, 20.9058874]}},
#   'created': '2022-03-23T12:41:22.327-05:00',
#   '_links': {'self': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/data/8382521003415179756-242ac1110-0001-012'},
#    'permissions': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/data/8382521003415179756-242ac1110-0001-012/pems'},
#    'owner': {'href': 'https://ikeauth.its.hawaii.edu/profiles/v2/ckkondo'},
#    'associationIds': []}}]

# %%
ike.searchMetadata("{'name':'GPS'}", 1)
# Out:
# [{'uuid': '3601472873912921620-242ac1110-0001-012',
#   'owner': 'ckkondo',
#   'schemaId': None,
#   'internalUsername': None,
#   'associationIds': [],
#   'lastUpdated': '2022-03-22T18:28:39.800-05:00',
#   'name': 'GPS',
#   'value': {'x': 18,
#    'location': 'Honokohau.Right.bowl',
#    'watershed': 'HONOKOHAU',
#    'site_enviro': 'Freshwater',
#    'site_type': 'Waterfall',
#    'site_salinity': 'Freshwater',
#    'lattitude': 20.90891,
#    'longitude': -156.58375,
#    'elevation': 778.5,
#    'max_elevation_watershed-m': 1761.0,
#    'wsp': 0.442078365,
#    'group_by_water_shed_percent': 'MAUKA.3',
#    'group_by_elevation': 'MAUKA.2',
#    'distribution': 1,
#    'watershed_order': 'HONOKOHAU_1',
#    'mauka': 'MAUKA',
#    'norm_order': 3,
#    'norm_watershed_order': 'HONOKOHAU_3',
#    'watershed_mauka': 'HONOKOHAU_MAUKA',
#    'type_norm_order': '1.Pristine_HONOKOHAU_3',
#    'loc': {'type': 'Point', 'coordinates': [-156.58375, 20.90891]}},
#   'created': '2022-03-22T18:28:39.800-05:00',
#   '_links': {'self': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/data/3601472873912921620-242ac1110-0001-012'},
#    'permissions': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/data/3601472873912921620-242ac1110-0001-012/pems'},
#    'owner': {'href': 'https://ikeauth.its.hawaii.edu/profiles/v2/ckkondo'},
#    'associationIds': []}}]

# %%
#This is how we use the ikewaipy search for JSON metadata objects - similiar to listMetadata

#ike.searchMetadata("{'name':'Variable','value.variable_name':'Temperature'}", 1)

ike.searchMetadata("{'name':'Well'}", 1)
# Out:
# [{'uuid': '3240980670745013785-242ac1110-0001-012',
#   'schemaId': '540303726288114151-242ac1110-0001-013',
#   'internalUsername': None,
#   'associationIds': ['5071768890026421785-242ac113-0001-002',
#    '5011639347882421785-242ac113-0001-002'],
#   'lastUpdated': '2019-07-11T15:30:43.833-05:00',
#   'name': 'Well',
#   'value': {'wid': '8-5352-001',
#    'island': 'Hawaii',
#    'well_name': 'West Hawaii Landfill',
#    'yr_drilled': 1993,
#    'ikewai_type': ['GeoChemistry', 'Microbial'],
#    'driller': "Wai'eli Drilling & Development",
#    'quad_map': 5,
#    'long83dd': '-155.875833',
#    'lat83dd': '19.888611',
#    'longitude': -155.875833,
#    'latitude': 19.888611,
#    'utm': True,
#    'owner_user': 'Waste Management of Hawaii, Inc.',
#    'land_owner': 'Land Division Oahu, DLNR-LD',
#    'pump_installer': 'Blaise Clay (Water Resources International, Inc.)',
#    'casing_dia': 8,
#    'ground_el': 191,
#    'well_depth': 220,
#    'solid_case': 188,
#    'perf_case': 206,
#    'use': 'INDMI',
#    'init_head': 2,
#    'init_cl': 910,
#    'test_date': '12/2/93',
#    'test_gpm': 275,
#    'test_ddown': '0.6',
#    'test_chlor': '920',
#    'test_temp': 22.2,
#    'test_unit': 'C',
#    'temp_f': '71.96',
#    'temp_c': '22.2',
#    'pump_gpm': 100,
#    'pump_yr': 1995,
#    'bot_hole': -29,
#    'bot_solid': 3,
#    'bot_perf': '-15',
#    'pump_mgd': 0.144,
#    'pump_depth': '198',
#    'surveyor': 'Wes Thomas Associates, Inc',
#    'loc': {'type': 'Point', 'coordinates': [-155.875833, 19.888611]}},
#   'created': '2017-06-28T18:09:23.540-05:00',
#   'owner': 'seanbc',
#   '_links': {'self': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/data/3240980670745013785-242ac1110-0001-012'},
#    'permissions': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/data/3240980670745013785-242ac1110-0001-012/pems'},
#    'owner': {'href': 'https://ikeauth.its.hawaii.edu/profiles/v2/seanbc'},
#    'associationIds': [{'rel': '5071768890026421785-242ac113-0001-002',
#      'href': 'https://ikeauth.its.hawaii.edu/files/v2/media/system/ikewai-annotated-data//Well_Data/Hawaii/8-5352-001.pdf',
#      'title': 'file'},
#     {'rel': '5011639347882421785-242ac113-0001-002',
#      'href': 'https://ikeauth.its.hawaii.edu/files/v2/media/system/ikewai-annotated-data//Well_Data/Hawaii/8-5352-001_map.pdf',
#      'title': 'file'}],
#    'SCHEMA': {'href': 'https://ikeauth.its.hawaii.edu/meta/v2/schemas/540303726288114151-242ac1110-0001-013'}}}]

# %%
#HTTP REST call to meta API with a mongo style query
def listMetadata(token, query="", limit=10, offset=0):
    safe_query = urllib.parse.quote(query.encode('utf8'))
    headers = {
        'authorization': "Bearer " + token,
        'content-type': "application/json",
    }
    res = requests.get('https://'+endpoint+'/meta/v2/data?q='+safe_query+'&limit='+str(limit)+'&offset='+str(offset), headers=headers,verify=False)
    resp = json.loads(res.content)
    return resp['result']

# %%
#HTTP API call to meta to fetch a single metadata JSON document by it's uuid
def getMetadata(token, uuid):
    headers = {
        'authorization': "Bearer " + token,
        'content-type': "application/json",
    }
    res = requests.get('https://'+endpoint+'/meta/v2/data/'+uuid, headers=headers,verify=False)
    resp = json.loads(res.content)
    return resp['result']

# %%
#HTTPS API call to update an existing metadata JSON document - note you have to pass every field as this is not a PATCH
def updateMetadata(token, uuid, data):
    headers = {
        'authorization': "Bearer " + token,
        'content-type': "application/json",
    }
    res = requests.post('https://'+endpoint+'/meta/v2/data/'+uuid, json=data, headers=headers,verify=False)
    resp = json.loads(res.content)
    return resp

# %%
#CREATE a new metadata document
def createMetadata(token, data):
    headers = {
        'authorization': "Bearer " + token,
        'content-type': "application/json",
        
    }
    res = requests.post('https://'+endpoint+'/meta/v2/data/', json=json.loads(data), headers=headers,verify=False)
    print(res.content)
    resp = json.loads(res.content)
    return resp

# %%
#permission needs to be READ READ-WRITE or ALL
def updateMetadataPem(token, uuid, username, permission):
    headers = {
        'authorization': "Bearer " + token,
        'content-type': "application/json",
        
    }
    data = {'permission':permission}
    res = requests.post('https://'+endpoint+'/meta/v2/data/'+uuid+'/pems/'+username, json=data, headers=headers,verify=False)
    resp = json.loads(res.content)
    return resp

# %%
def getMetadataPems(token,uuid):
    headers = {
        'authorization': "Bearer " + token,
        'content-type': "application/json",
    }
    res = requests.get('https://'+endpoint+'/meta/v2/data/'+uuid+'/pems/', headers=headers,verify=False)
    resp = json.loads(res.content)
    return resp

# %%
#load csv in a dataframe example and see dataframe
df1 = pd.read_csv('GPS.csv')
df1
# Out:
#        x         location   watershed site_enviro    site_type site_salinity  \
# 0      1          Honolii     HONOLII      Marine        Ocean        Marine
# 1      2      Onekahakaha    KEAUKAHA      Marine        Ocean        Marine
# 2      3         Puhi_Bay    KEAUKAHA      Marine        Ocean        Marine
# 3      4       Richardson    KEAUKAHA      Marine        Ocean        Marine
# 4      5      Kalapahapuu  KOHOLALELE  Freshwater       Stream    Freshwater
# ..   ...              ...         ...         ...          ...           ...
# 226  227      N3_KahaluuB     KEAUHOU  Freshwater  Groundwater    Freshwater
# 227  228      N3_KahaluuA     KEAUHOU  Freshwater  Groundwater    Freshwater
# 228  229  N3_KahaluuShaft     KEAUHOU  Freshwater  Groundwater    Freshwater
# 229  230       Koholalele  KOHOLALELE      Marine        Ocean        Marine
# 230  231          Lepelau  KOHOLALELE  Freshwater       Stream    Freshwater
#
#      lattitude   longitude  elevation  max_elevation_watershed-m       wsp  \
# 0    19.756377 -155.090424        0.0                       39.2  0.000000
# 1    19.738583 -155.039120        0.0                        6.6  0.000000
# 2    19.732241 -155.046373        0.0                        6.6  0.000000
# 3    19.736927 -155.013564        0.0                        6.6  0.000000
# 4    20.033667 -155.355350      219.4                     1964.0  0.111711
# ..         ...         ...        ...                        ...       ...
# 226  19.581667 -155.949722      254.9                     1571.0  0.162253
# 227  19.583056 -155.949722      253.5                     1571.0  0.161362
# 228  19.581356 -155.954122      178.3                     1571.0  0.113495
# 229  20.048624 -155.350672        3.9                     1964.0  0.001986
# 230  20.021234 -155.359813      417.6                     1964.0  0.212627
#
#     group_by_water_shed_percent group_by_elevation  distribution  \
# 0                           KAI                KAI             1
# 1                           KAI                KAI             1
# 2                           KAI                KAI             1
# 3                           KAI                KAI             1
# 4                         MID.2              MID.1             2
# ..                          ...                ...           ...
# 226                       MID.2            MAUKA.3             8
# 227                       MID.2            MAUKA.3             8
# 228                       MID.2              MID.1             9
# 229                       MAKAI              MAKAI             3
# 230                       MID.1            MAUKA.3             1
#
#     watershed_order  mauka  norm_order norm_watershed_order   watershed_mauka  \
# 0         HONOLII_1    KAI          10           HONOLII_10       HONOLII_KAI
# 1        KEAUKAHA_1    KAI          10          KEAUKAHA_10      KEAUKAHA_KAI
# 2        KEAUKAHA_1    KAI          10          KEAUKAHA_10      KEAUKAHA_KAI
# 3        KEAUKAHA_1    KAI          10          KEAUKAHA_10      KEAUKAHA_KAI
# 4      KOHOLALELE_2   KALA           5         KOHOLALELE_5   KOHOLALELE_KALA
# ..              ...    ...         ...                  ...               ...
# 226       KEAUHOU_8   KALA           4            KEAUHOU_4      KEAUHOU_KALA
# 227       KEAUHOU_8   KALA           4            KEAUHOU_4      KEAUHOU_KALA
# 228       KEAUHOU_9   KALA           4            KEAUHOU_4      KEAUHOU_KALA
# 229    KOHOLALELE_3  MAKAI           7         KOHOLALELE_7  KOHOLALELE_MAKAI
# 230    KOHOLALELE_1  MAUKA           3         KOHOLALELE_3  KOHOLALELE_MAUKA
#
#               type_norm_order
# 0          3.Urban_HONOLII_10
# 1         3.Urban_KEAUKAHA_10
# 2         3.Urban_KEAUKAHA_10
# 3         3.Urban_KEAUKAHA_10
# 4        3.Urban_KOHOLALELE_5
# ..                        ...
# 226  2.Aggriculture_KEAUHOU_4
# 227  2.Aggriculture_KEAUHOU_4
# 228  2.Aggriculture_KEAUHOU_4
# 229      3.Urban_KOHOLALELE_7
# 230      3.Urban_KOHOLALELE_3
#
# [231 rows x 20 columns]

# %%
#Parse a CSV file and convert it to JSON metadata documents

#read in csv file to a pandas dataframe
df1 = pd.read_csv('GPS.csv')

#set static json body values and permsissions
#users needs to exist in agave
body={}
pem1={}
pem1['username']= 'chazk'
pem1['permission']='ALL'
pem2={}
pem2['username']= 'jgeis'
pem2['permission']='ALL'
pem4={}
pem4['username']= 'ikewai-admin'
pem4['permission']='ALL'
pem5={}
pem5['username']= 'public'
pem5['permission']='READ'

#the name field should be the larger document type we want - so this should be akin to the CSV file - we will use this for searching for these document types
body['name'] = "test___"

#add our permissions to the document body so they are set at creation
body['permissions']=[pem1,pem2,pem4,pem5]


#should loop through each dataframe row convert to json 
i=0
ls = [0,1,2]
for i in df1.index:
    j = df1.loc[i].to_json()
    js = json.loads(j)
    #This stores a GeoJSON object in the value.loc field - in Ike Wai this has a spatial index on it in mongodb
    #ONLY DO THIS FOR georeferenced documents - so probably just one CSV
    js['loc'] = {"type":"Point", "coordinates":[js['longitude'],js['lattitude']]}
    body['value'] = js
    body['geospatial']= True;
    #preview our JSON document
    # print(body)
    #create the document in Ike Wai - 
    createMetadata(ike.token,json.dumps(body))
# Out:
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 1, 'location': 'Honolii', 'watershed': 'HONOLII', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 19.7563774, 'longitude': -155.0904238, 'elevation': 0.0, 'max_elevation_watershed-m': 39.2, 'wsp': 0.0, 'group_by_water_shed_percent': 'KAI', 'group_by_elevation': 'KAI', 'distribution': 1, 'watershed_order': 'HONOLII_1', 'mauka': 'KAI', 'norm_order': 10, 'norm_watershed_order': 'HONOLII_10', 'watershed_mauka': 'HONOLII_KAI', 'type_norm_order': '3.Urban_HONOLII_10', 'loc': {'type': 'Point', 'coordinates': [-155.0904238, 19.7563774]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 2, 'location': 'Onekahakaha', 'watershed': 'KEAUKAHA', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 19.7385834, 'longitude': -155.0391203, 'elevation': 0.0, 'max_elevation_watershed-m': 6.6, 'wsp': 0.0, 'group_by_water_shed_percent': 'KAI', 'group_by_elevation': 'KAI', 'distribution': 1, 'watershed_order': 'KEAUKAHA_1', 'mauka': 'KAI', 'norm_order': 10, 'norm_watershed_order': 'KEAUKAHA_10', 'watershed_mauka': 'KEAUKAHA_KAI', 'type_norm_order': '3.Urban_KEAUKAHA_10', 'loc': {'type': 'Point', 'coordinates': [-155.0391203, 19.7385834]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 3, 'location': 'Puhi_Bay', 'watershed': 'KEAUKAHA', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 19.7322414, 'longitude': -155.046373, 'elevation': 0.0, 'max_elevation_watershed-m': 6.6, 'wsp': 0.0, 'group_by_water_shed_percent': 'KAI', 'group_by_elevation': 'KAI', 'distribution': 1, 'watershed_order': 'KEAUKAHA_1', 'mauka': 'KAI', 'norm_order': 10, 'norm_watershed_order': 'KEAUKAHA_10', 'watershed_mauka': 'KEAUKAHA_KAI', 'type_norm_order': '3.Urban_KEAUKAHA_10', 'loc': {'type': 'Point', 'coordinates': [-155.046373, 19.7322414]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 4, 'location': 'Richardson', 'watershed': 'KEAUKAHA', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 19.7369272, 'longitude': -155.0135642, 'elevation': 0.0, 'max_elevation_watershed-m': 6.6, 'wsp': 0.0, 'group_by_water_shed_percent': 'KAI', 'group_by_elevation': 'KAI', 'distribution': 1, 'watershed_order': 'KEAUKAHA_1', 'mauka': 'KAI', 'norm_order': 10, 'norm_watershed_order': 'KEAUKAHA_10', 'watershed_mauka': 'KEAUKAHA_KAI', 'type_norm_order': '3.Urban_KEAUKAHA_10', 'loc': {'type': 'Point', 'coordinates': [-155.0135642, 19.7369272]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 5, 'location': 'Kalapahapuu', 'watershed': 'KOHOLALELE', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.0336668, 'longitude': -155.3553501, 'elevation': 219.4, 'max_elevation_watershed-m': 1964.0, 'wsp': 0.111710794, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MID.1', 'distribution': 2, 'watershed_order': 'KOHOLALELE_2', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'KOHOLALELE_5', 'watershed_mauka': 'KOHOLALELE_KALA', 'type_norm_order': '3.Urban_KOHOLALELE_5', 'loc': {'type': 'Point', 'coordinates': [-155.3553501, 20.0336668]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 6, 'location': 'Koholalele_Kai', 'watershed': 'KOHOLALELE', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 20.0486243, 'longitude': -155.3506723, 'elevation': 3.9, 'max_elevation_watershed-m': 1964.0, 'wsp': 0.001985743, 'group_by_water_shed_percent': 'MAKAI', 'group_by_elevation': 'MAKAI', 'distribution': 3, 'watershed_order': 'KOHOLALELE_3', 'mauka': 'MAKAI', 'norm_order': 7, 'norm_watershed_order': 'KOHOLALELE_7', 'watershed_mauka': 'KOHOLALELE_MAKAI', 'type_norm_order': '3.Urban_KOHOLALELE_7', 'loc': {'type': 'Point', 'coordinates': [-155.3506723, 20.0486243]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 7, 'location': 'KaluaoLono_punawai_Lepelau', 'watershed': 'KOHOLALELE', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.0212343, 'longitude': -155.3598134, 'elevation': 417.6, 'max_elevation_watershed-m': 1964.0, 'wsp': 0.212627291, 'group_by_water_shed_percent': 'MID.1', 'group_by_elevation': 'MAUKA.3', 'distribution': 1, 'watershed_order': 'KOHOLALELE_1', 'mauka': 'MAUKA', 'norm_order': 3, 'norm_watershed_order': 'KOHOLALELE_3', 'watershed_mauka': 'KOHOLALELE_MAUKA', 'type_norm_order': '3.Urban_KOHOLALELE_3', 'loc': {'type': 'Point', 'coordinates': [-155.3598134, 20.0212343]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 8, 'location': 'Kahua_Waipunalau', 'watershed': 'PAAUILO', 'site_enviro': 'Freshwater', 'site_type': 'Spring', 'site_salinity': 'Freshwater', 'lattitude': 20.0135854, 'longitude': -155.3816968, 'elevation': 592.8, 'max_elevation_watershed-m': 1210.0, 'wsp': 0.489917355, 'group_by_water_shed_percent': 'MAUKA.3', 'group_by_elevation': 'MAUKA.2', 'distribution': 1, 'watershed_order': 'PAAUILO_1', 'mauka': 'MAUKA', 'norm_order': 3, 'norm_watershed_order': 'PAAUILO_3', 'watershed_mauka': 'PAAUILO_MAUKA', 'type_norm_order': '3.Urban_PAAUILO_3', 'loc': {'type': 'Point', 'coordinates': [-155.3816968, 20.0135854]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 9, 'location': 'Waihalulu', 'watershed': 'PAAUILO', 'site_enviro': 'Freshwater', 'site_type': 'Spring', 'site_salinity': 'Freshwater', 'lattitude': 20.0361651, 'longitude': -155.3738004, 'elevation': 293.7, 'max_elevation_watershed-m': 1210.0, 'wsp': 0.242727273, 'group_by_water_shed_percent': 'MID.1', 'group_by_elevation': 'MAUKA.3', 'distribution': 2, 'watershed_order': 'PAAUILO_2', 'mauka': 'KALA', 'norm_order': 4, 'norm_watershed_order': 'PAAUILO_4', 'watershed_mauka': 'PAAUILO_KALA', 'type_norm_order': '2.Aggriculture_PAAUILO_4', 'loc': {'type': 'Point', 'coordinates': [-155.3738004, 20.0361651]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 10, 'location': 'Waipunalau_Paauilo', 'watershed': 'PAAUILO', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.0404414, 'longitude': -155.3710279, 'elevation': 233.6, 'max_elevation_watershed-m': 1210.0, 'wsp': 0.193057851, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MID.1', 'distribution': 3, 'watershed_order': 'PAAUILO_3', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'PAAUILO_5', 'watershed_mauka': 'PAAUILO_KALA', 'type_norm_order': '2.Aggriculture_PAAUILO_5', 'loc': {'type': 'Point', 'coordinates': [-155.3710279, 20.0404414]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 11, 'location': 'Waipunalau_Pakii', 'watershed': 'PAAUILO', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.0404414, 'longitude': -155.3710279, 'elevation': 233.6, 'max_elevation_watershed-m': 1210.0, 'wsp': 0.193057851, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MID.1', 'distribution': 3, 'watershed_order': 'PAAUILO_3', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'PAAUILO_5', 'watershed_mauka': 'PAAUILO_KALA', 'type_norm_order': '2.Aggriculture_PAAUILO_5', 'loc': {'type': 'Point', 'coordinates': [-155.3710279, 20.0404414]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 12, 'location': 'Bayfront', 'watershed': 'WAILOA', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 19.7237177, 'longitude': -155.0739247, 'elevation': 0.0, 'max_elevation_watershed-m': 2.0, 'wsp': 0.0, 'group_by_water_shed_percent': 'KAI', 'group_by_elevation': 'KAI', 'distribution': 1, 'watershed_order': 'WAILOA_1', 'mauka': 'KAI', 'norm_order': 10, 'norm_watershed_order': 'WAILOA_10', 'watershed_mauka': 'WAILOA_KAI', 'type_norm_order': '1.Pristine_WAILOA_10', 'loc': {'type': 'Point', 'coordinates': [-155.0739247, 19.7237177]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 13, 'location': 'Reeds_Bay', 'watershed': 'WAILOA', 'site_enviro': 'Marine', 'site_type': 'Ocean', 'site_salinity': 'Marine', 'lattitude': 19.7258184, 'longitude': -155.0626808, 'elevation': 0.0, 'max_elevation_watershed-m': 2.0, 'wsp': 0.0, 'group_by_water_shed_percent': 'KAI', 'group_by_elevation': 'KAI', 'distribution': 1, 'watershed_order': 'WAILOA_1', 'mauka': 'KAI', 'norm_order': 10, 'norm_watershed_order': 'WAILOA_10', 'watershed_mauka': 'WAILOA_KAI', 'type_norm_order': '1.Pristine_WAILOA_10', 'loc': {'type': 'Point', 'coordinates': [-155.0626808, 19.7258184]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 14, 'location': 'Honokohau.Bowl', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Waterfall', 'site_salinity': 'Freshwater', 'lattitude': 20.90891, 'longitude': -156.58375, 'elevation': 778.5, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.442078365, 'group_by_water_shed_percent': 'MAUKA.3', 'group_by_elevation': 'MAUKA.2', 'distribution': 1, 'watershed_order': 'HONOKOHAU_1', 'mauka': 'MAUKA', 'norm_order': 3, 'norm_watershed_order': 'HONOKOHAU_3', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_3', 'loc': {'type': 'Point', 'coordinates': [-156.58375, 20.90891]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 15, 'location': 'Honokohau.crossing', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 21.008158, 'longitude': -156.606245, 'elevation': 28.6, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.016240772, 'group_by_water_shed_percent': 'MAKAI', 'group_by_elevation': 'MAKAI', 'distribution': 4, 'watershed_order': 'HONOKOHAU_4', 'mauka': 'MAKAI', 'norm_order': 8, 'norm_watershed_order': 'HONOKOHAU_8', 'watershed_mauka': 'HONOKOHAU_MAKAI', 'type_norm_order': '1.Pristine_HONOKOHAU_8', 'loc': {'type': 'Point', 'coordinates': [-156.606245, 21.008158]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 16, 'location': 'Honokohau.loi.hoi', 'watershed': 'HONOKOHAU', 'site_enviro': 'Agriculture', 'site_type': 'Loi', 'site_salinity': 'Freshwater', 'lattitude': 21.008654, 'longitude': -156.606187, 'elevation': 28.7, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.016297558, 'group_by_water_shed_percent': 'MAKAI', 'group_by_elevation': 'MAKAI', 'distribution': 4, 'watershed_order': 'HONOKOHAU_4', 'mauka': 'MAKAI', 'norm_order': 8, 'norm_watershed_order': 'HONOKOHAU_8', 'watershed_mauka': 'HONOKOHAU_MAKAI', 'type_norm_order': '1.Pristine_HONOKOHAU_8', 'loc': {'type': 'Point', 'coordinates': [-156.606187, 21.008654]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 17, 'location': 'Honokohau.muliwai', 'watershed': 'HONOKOHAU', 'site_enviro': 'Brackish', 'site_type': 'Muliwai', 'site_salinity': 'Brackish', 'lattitude': 21.020774, 'longitude': -156.609344, 'elevation': 1.3, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.000738217, 'group_by_water_shed_percent': 'MAKAI', 'group_by_elevation': 'MAKAI', 'distribution': 5, 'watershed_order': 'HONOKOHAU_5', 'mauka': 'MAKAI', 'norm_order': 8, 'norm_watershed_order': 'HONOKOHAU_8', 'watershed_mauka': 'HONOKOHAU_MAKAI', 'type_norm_order': '1.Pristine_HONOKOHAU_8', 'loc': {'type': 'Point', 'coordinates': [-156.609344, 21.020774]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 18, 'location': 'Honokohau.Right.bowl', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Waterfall', 'site_salinity': 'Freshwater', 'lattitude': 20.90891, 'longitude': -156.58375, 'elevation': 778.5, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.442078365, 'group_by_water_shed_percent': 'MAUKA.3', 'group_by_elevation': 'MAUKA.2', 'distribution': 1, 'watershed_order': 'HONOKOHAU_1', 'mauka': 'MAUKA', 'norm_order': 3, 'norm_watershed_order': 'HONOKOHAU_3', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_3', 'loc': {'type': 'Point', 'coordinates': [-156.58375, 20.90891]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 19, 'location': 'Honokohau.Right.wall', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Waterfall', 'site_salinity': 'Freshwater', 'lattitude': 20.90891, 'longitude': -156.58375, 'elevation': 778.5, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.442078365, 'group_by_water_shed_percent': 'MAUKA.3', 'group_by_elevation': 'MAUKA.2', 'distribution': 1, 'watershed_order': 'HONOKOHAU_1', 'mauka': 'MAUKA', 'norm_order': 3, 'norm_watershed_order': 'HONOKOHAU_3', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_3', 'loc': {'type': 'Point', 'coordinates': [-156.58375, 20.90891]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 20, 'location': 'Honokohau.Transect.1.O', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.961867, 'longitude': -156.585567, 'elevation': 346.0, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.196479273, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MAUKA.3', 'distribution': 2, 'watershed_order': 'HONOKOHAU_2', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'HONOKOHAU_5', 'watershed_mauka': 'HONOKOHAU_KALA', 'type_norm_order': '1.Pristine_HONOKOHAU_5', 'loc': {'type': 'Point', 'coordinates': [-156.585567, 20.961867]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 21, 'location': 'Honokohau.Transect.15.Q', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.960817, 'longitude': -156.586517, 'elevation': 269.8, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.153208404, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MAUKA.3', 'distribution': 3, 'watershed_order': 'HONOKOHAU_3', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'HONOKOHAU_5', 'watershed_mauka': 'HONOKOHAU_KALA', 'type_norm_order': '1.Pristine_HONOKOHAU_5', 'loc': {'type': 'Point', 'coordinates': [-156.586517, 20.960817]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 22, 'location': 'Honokohau.Transect.6.P', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.961433, 'longitude': -156.586467, 'elevation': 269.4, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.152981261, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MAUKA.3', 'distribution': 3, 'watershed_order': 'HONOKOHAU_3', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'HONOKOHAU_5', 'watershed_mauka': 'HONOKOHAU_KALA', 'type_norm_order': '1.Pristine_HONOKOHAU_5', 'loc': {'type': 'Point', 'coordinates': [-156.586467, 20.961433]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 23, 'location': 'Honokohau.USGS.gauge.upstream', 'watershed': 'HONOKOHAU', 'site_enviro': 'Freshwater', 'site_type': 'Stream', 'site_salinity': 'Freshwater', 'lattitude': 20.960017, 'longitude': -156.587017, 'elevation': 274.0, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.155593413, 'group_by_water_shed_percent': 'MID.2', 'group_by_elevation': 'MAUKA.3', 'distribution': 3, 'watershed_order': 'HONOKOHAU_3', 'mauka': 'KALA', 'norm_order': 5, 'norm_watershed_order': 'HONOKOHAU_5', 'watershed_mauka': 'HONOKOHAU_KALA', 'type_norm_order': '1.Pristine_HONOKOHAU_5', 'loc': {'type': 'Point', 'coordinates': [-156.587017, 20.960017]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 24, 'location': 'Bog.0m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.890355, 'longitude': -156.5862045, 'elevation': 1756.6, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.99750142, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 1, 'watershed_order': 'HONOKOHAU_1', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '2.Aggriculture_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.5862045, 20.890355]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 25, 'location': 'Bog.1000m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.8991984, 'longitude': -156.5883429, 'elevation': 1615.4, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.917319705, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 3, 'watershed_order': 'HONOKOHAU_3', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.5883429, 20.8991984]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 26, 'location': 'Bog.100m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.8914899, 'longitude': -156.5866428, 'elevation': 1746.6, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.991822828, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 1, 'watershed_order': 'HONOKOHAU_1', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '2.Aggriculture_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.5866428, 20.8914899]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 27, 'location': 'Bog.1100m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9000592, 'longitude': -156.5886782, 'elevation': 1605.8, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.911868257, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 3, 'watershed_order': 'HONOKOHAU_3', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.5886782, 20.9000592]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 28, 'location': 'Bog.1200m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9008134, 'longitude': -156.589232, 'elevation': 1596.8, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.906757524, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 4, 'watershed_order': 'HONOKOHAU_4', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.589232, 20.9008134]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 29, 'location': 'Bog.1300m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9016202, 'longitude': -156.5896451, 'elevation': 1584.4, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.89971607, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 4, 'watershed_order': 'HONOKOHAU_4', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.5896451, 20.9016202]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 30, 'location': 'Bog.1400m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9023942, 'longitude': -156.5900763, 'elevation': 1564.8, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.888586031, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 4, 'watershed_order': 'HONOKOHAU_4', 'mauka': 'MAUKA', 'norm_order': 1, 'norm_watershed_order': 'HONOKOHAU_1', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_1', 'loc': {'type': 'Point', 'coordinates': [-156.5900763, 20.9023942]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 31, 'location': 'Bog.1500m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9030018, 'longitude': -156.5908475, 'elevation': 1549.4, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.879840999, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 5, 'watershed_order': 'HONOKOHAU_5', 'mauka': 'MAUKA', 'norm_order': 2, 'norm_watershed_order': 'HONOKOHAU_2', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_2', 'loc': {'type': 'Point', 'coordinates': [-156.5908475, 20.9030018]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 32, 'location': 'Bog.1600m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9038875, 'longitude': -156.5912149, 'elevation': 1536.9, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.87274276, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 5, 'watershed_order': 'HONOKOHAU_5', 'mauka': 'MAUKA', 'norm_order': 2, 'norm_watershed_order': 'HONOKOHAU_2', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_2', 'loc': {'type': 'Point', 'coordinates': [-156.5912149, 20.9038875]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 33, 'location': 'Bog.1700m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9043693, 'longitude': -156.591891, 'elevation': 1527.6, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.86746167, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 5, 'watershed_order': 'HONOKOHAU_5', 'mauka': 'MAUKA', 'norm_order': 2, 'norm_watershed_order': 'HONOKOHAU_2', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_2', 'loc': {'type': 'Point', 'coordinates': [-156.591891, 20.9043693]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 34, 'location': 'Bog.1800m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9050969, 'longitude': -156.5922918, 'elevation': 1516.2, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.860988075, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 5, 'watershed_order': 'HONOKOHAU_5', 'mauka': 'MAUKA', 'norm_order': 2, 'norm_watershed_order': 'HONOKOHAU_2', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_2', 'loc': {'type': 'Point', 'coordinates': [-156.5922918, 20.9050969]}}, 'geospatial': True}
# b'{"status":"error","message":"An error occurred while fetching the metadata item. If this problem persists, please contact the system administrators.","version":"2.2.22-r7deb380"}'
# {'name': 'Micro_GPS_TEST', 'permissions': [{'username': 'chazk', 'permission': 'ALL'}, {'username': 'jgeis', 'permission': 'ALL'}, {'username': 'ikewai-admin', 'permission': 'ALL'}, {'username': 'public', 'permission': 'READ'}], 'value': {'x': 35, 'location': 'Bog.1900m', 'watershed': 'HONOKOHAU', 'site_enviro': 'NativeForest', 'site_type': 'Bog', 'site_salinity': 'Freshwater', 'lattitude': 20.9058874, 'longitude': -156.5925963, 'elevation': 1501.5, 'max_elevation_watershed-m': 1761.0, 'wsp': 0.852640545, 'group_by_water_shed_percent': 'MAUKA.1', 'group_by_elevation': 'MAUKA.1', 'distribution': 6, 'watershed_order': 'HONOKOHAU_6', 'mauka': 'MAUKA', 'norm_order': 2, 'norm_watershed_order': 'HONOKOHAU_2', 'watershed_mauka': 'HONOKOHAU_MAUKA', 'type_norm_order': '1.Pristine_HONOKOHAU_2', 'loc': {'type': 'Point', 'coordinates': [-156.5925963, 20.9058874]}}, 'geospatial': True}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_19/2568156018.py in <module>
#      41     print(body)
#      42     #create the document in Ike Wai -
# ---> 43     createMetadata(ike.token,json.dumps(body))
#      44
#
# /tmp/ipykernel_19/2890714026.py in createMetadata(token, data)
#       6
#       7     }
# ----> 8     res = requests.post('https://'+endpoint+'/meta/v2/data/', json=json.loads(data), headers=headers,verify=False)
#       9     print(res.content)
#      10     resp = json.loads(res.content)
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     115     """
#     116
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#     118
#     119
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     decode_content=False,
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#     452
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /usr/local/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/local/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/local/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/local/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
endpoint = 'ikeauth.its.hawaii.edu'

# %%
updateMetadataPem(ike.token, '3601472873912921620-242ac1110-0001-012', 'public', 'READ')
# Out:
# {'status': 'error',
#  'message': 'User does not have permission to edit public metadata item permissions',
#  'version': '2.2.22-r7deb380'}
